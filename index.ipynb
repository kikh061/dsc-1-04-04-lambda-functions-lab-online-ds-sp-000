# %% [markdown]
# # Lambda Functions - Lab

# %% [markdown]
# ## Introduction|
#
# In this lab, you'll get some hands on practice creating and using lambda functions.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand what lambda functions are and why they are useful
# * Use lambda functions to transform data within lists and DataFrames

# %% [markdown]
# ## Lambda Functions

# %%
import pandas as pd
df = pd.read_csv('Yelp_Reviews.csv')
df.head(2)
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
#
#                   user_id
# 0  msQe1u7Z_XuqjGoqhB0J5g
# 1  msQe1u7Z_XuqjGoqhB0J5g

# %% [markdown]
# # Simple Arithmetic
#
# Use a lambda function to create a new column called 'stars_squared' by squarring the stars column.

# %%
df['stars_squared'] = df.stars.map(lambda x: x**2)
df.head()
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
#                   user_id  stars_squared
# 0  msQe1u7Z_XuqjGoqhB0J5g             25
# 1  msQe1u7Z_XuqjGoqhB0J5g              1
# 2  msQe1u7Z_XuqjGoqhB0J5g             25
# 3  msQe1u7Z_XuqjGoqhB0J5g              1
# 4  TlvV-xJhmh7LCwJYXkV-cg             25

# %% [markdown]
# # Dates
# Select the month from the date string using a lambda function.

# %%
df.date.map(lambda x: x[:4])
# Out:
# 0       2012
# 1       2014
# 2       2014
# 3       2011
# 4       2016
# 5       2016
# 6       2014
# 7       2017
# 8       2017
# 9       2017
# 10      2015
# 11      2012
# 12      2012
# 13      2012
# 14      2012
# 15      2014
# 16      2016
# 17      2015
# 18      2015
# 19      2017
# 20      2016
# 21      2016
# 22      2016
# 23      2012
# 24      2017
# 25      2017
# 26      2010
# 27      2016
# 28      2016
# 29      2016
#         ...
# 2580    2015
# 2581    2013
# 2582    2016
# 2583    2015
# 2584    2017
# 2585    2015
# 2586    2015
# 2587    2012
# 2588    2015
# 2589    2015
# 2590    2007
# 2591    2016
# 2592    2015
# 2593    2013
# 2594    2011
# 2595    2014
# 2596    2014
# 2597    2016
# 2598    2011
# 2599    2014
# 2600    2012
# 2601    2014
# 2602    2012
# 2603    2013
# 2604    2013
# 2605    2013
# 2606    2016
# 2607    2016
# 2608    2013
# 2609    2016
# Name: date, Length: 2610, dtype: object

# %%
#from answer sheet
df.date.map(lambda x: x[-2:]).head()
# Out:
# 0    13
# 1    23
# 2    05
# 3    25
# 4    15
# Name: date, dtype: object

# %% [markdown]
# # What is the average number of words for a yelp review?
# Do this with a single line of code!

# %%
df.text.map(lambda x: len(x.split())).sum()/len(df)
# Out:
# 77.06551724137931

# %% [markdown]
# # Create a new column for the number of words in the review.

# %%
df['words_count'] = df.text.map(lambda x: len(x.split()))
df.head()
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
#                   user_id  stars_squared  words_count
# 0  msQe1u7Z_XuqjGoqhB0J5g             25           58
# 1  msQe1u7Z_XuqjGoqhB0J5g              1           30
# 2  msQe1u7Z_XuqjGoqhB0J5g             25           30
# 3  msQe1u7Z_XuqjGoqhB0J5g              1           82
# 4  TlvV-xJhmh7LCwJYXkV-cg             25           32

# %% [markdown]
# ## Rewrite the following as a lamda function. Create a new column 'Review_Length'

# %%
def rewrite_as_lambda(value):
    if len(value) < 50:
        return 'Short'
    elif len(value) < 80:
        return 'Medium'
    else:
        return 'Long'
#Hint: nest your if, else conditionals

# %%
df['Review_Length'] = df.text.map(lambda x: 'Short' if len(x.split())<50 else ('Medium' if len(x.split()) < 80 else 'Long' ) )
df.head(10)
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
# 5          11  UBv8heCQR0RPnUQG0zkXIQ     0  2016-09-23      0
# 6          12  hdgYnadxg0GANhWOJabr2g     0  2014-08-23      0
# 7          19  gZGsReG0VeX4uKViHTB9EQ     0  2017-08-16      0
# 8          25  f-v1fvtnbdw_QQRsCnwH-g     0  2017-11-18      0
# 9          26  yz66FIUPDKGhILDWzRLeKg     0  2017-11-18      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
# 5  HkYqGb0Gplmmk-xlHTRBoA      1
# 6  RgqWdZA4xR023iP3T6jVfA      5
# 7  51RHs_V_fjuistnuKxNpEg      5
# 8  alI_kRKyEHfdHibYGgtJbw      1
# 9  85DRIjwPJOTb4q0qOlBstw      1
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
# 5  The score should be negative. Its HORRIBLE. Th...       0
# 6  I went there twice and I am pretty happy with ...       0
# 7  Finally! After trying many Mexican restaurants...       0
# 8  I have to write a review on the Fractured Prun...       0
# 9  I wish i could tell you all about the food but...       1
#
#                   user_id  stars_squared  words_count Review_Length
# 0  msQe1u7Z_XuqjGoqhB0J5g             25           58        Medium
# 1  msQe1u7Z_XuqjGoqhB0J5g              1           30         Short
# 2  msQe1u7Z_XuqjGoqhB0J5g             25           30         Short
# 3  msQe1u7Z_XuqjGoqhB0J5g              1           82          Long
# 4  TlvV-xJhmh7LCwJYXkV-cg             25           32         Short
# 5  NhOc64RsrTT1Dls50yYW8g              1           49         Short
# 6  NhOc64RsrTT1Dls50yYW8g             25           21         Short
# 7  5ngpW5tf3ep680eG1HxHzA             25           70        Medium
# 8  Fc_nb6N6Sdurqb-rwsY1Bw              1          131          Long
# 9  Fc_nb6N6Sdurqb-rwsY1Bw              1          112          Long

# %% [markdown]
# # Level Up: Dates Adavanced!
# <img src="date_format_map.png" width=500>
#
# Overwrite the date column by reordering the month and day from YYYY-MM-DD to DD-MM-YYYY. Try to do this using a lambda function.

# %%
import datetime
import time

df['date2'] = df.date.map(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").strftime('%d-%m-%Y'))
df.head()
# Out:
#    Unnamed: 0             business_id  cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw      5
# 1  LZp4UX5zK3e-c5ZGSeo3kA      1
# 2  jsDu6QEJHbwP2Blom1PLCA      5
# 3  pfavA0hr3nyqO61oupj-lA      1
# 4  STiFMww2z31siPY7BWNC2g      5
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
#                   user_id       date2
# 0  msQe1u7Z_XuqjGoqhB0J5g  13-11-2012
# 1  msQe1u7Z_XuqjGoqhB0J5g  23-10-2014
# 2  msQe1u7Z_XuqjGoqhB0J5g  05-09-2014
# 3  msQe1u7Z_XuqjGoqhB0J5g  25-02-2011
# 4  TlvV-xJhmh7LCwJYXkV-cg  15-06-2016

# %%
#from answer sheet

df.date.map(lambda x: '{}-{}-{}'.format(x[-2:], x[5:7], x[:4]))
# Out:
# 0       13-11-2012
# 1       23-10-2014
# 2       05-09-2014
# 3       25-02-2011
# 4       15-06-2016
# 5       23-09-2016
# 6       23-08-2014
# 7       16-08-2017
# 8       18-11-2017
# 9       18-11-2017
# 10      10-12-2015
# 11      12-02-2012
# 12      12-02-2012
# 13      12-02-2012
# 14      12-02-2012
# 15      03-06-2014
# 16      18-11-2016
# 17      05-11-2015
# 18      05-11-2015
# 19      21-01-2017
# 20      06-11-2016
# 21      28-05-2016
# 22      08-05-2016
# 23      11-10-2012
# 24      08-04-2017
# 25      09-04-2017
# 26      17-11-2010
# 27      10-04-2016
# 28      10-03-2016
# 29      24-02-2016
#            ...
# 2580    08-09-2015
# 2581    12-07-2013
# 2582    27-07-2016
# 2583    12-10-2015
# 2584    20-06-2017
# 2585    17-10-2015
# 2586    25-06-2015
# 2587    14-08-2012
# 2588    02-07-2015
# 2589    22-03-2015
# 2590    02-10-2007
# 2591    17-07-2016
# 2592    03-08-2015
# 2593    28-08-2013
# 2594    25-08-2011
# 2595    27-02-2014
# 2596    01-07-2014
# 2597    20-08-2016
# 2598    01-08-2011
# 2599    27-01-2014
# 2600    14-06-2012
# 2601    14-01-2014
# 2602    19-05-2012
# 2603    01-03-2013
# 2604    03-11-2013
# 2605    02-06-2013
# 2606    14-08-2016
# 2607    14-06-2016
# 2608    02-10-2013
# 2609    15-08-2016
# Name: date, Length: 2610, dtype: object

# %% [markdown]
# ## Summary
#
# Great! Hopefully you're getting the hang of lambda functions now! It's important not to overuse them - it will often make more sense to define a function so that it's reusable elsewhere. But whenever you need to quickly apply some simple processing to a collection of data you have a new technique that will help you to do just that. It'll also be useful if you're reading someone elses code that happens to use lambdas.
